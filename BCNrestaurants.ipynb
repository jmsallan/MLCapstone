# %% [markdown]
# <h1 align=center><font size = 5>Restaurants in Barcelona Neighbourhoods</font></h1>

# %% [markdown]
# The aim of this notebook is to classify Barcelona neighbourhoods using the type of restaurants existing in each neighbourhood.

# %% [markdown]
# Let's import the required libraries:

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import re #for regular expressions

from bs4 import BeautifulSoup #for web scraping

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Scraping coordinates of Barcelona neighbourhoods

# %% [markdown]
# We will start by getting a Pandas dataframe listing all Barcelona neighbourhoods and their coordinates. We will do so scraping Wikipedia website using BeautifulSoup. First, we will get the list of neighbourhood links from the list of neighbourhoods Wikipedia website: https://es.wikipedia.org/wiki/Categor%C3%ADa:Barrios_de_Barcelona

# %%
website_url = requests.get("https://es.wikipedia.org/wiki/Categor%C3%ADa:Barrios_de_Barcelona").text

soup = BeautifulSoup(website_url,"lxml")
main_tag = soup.findAll('div',{'id':'mw-content-text'})[0]

LinkList = list()
for a in main_tag.find_all('a', href=True):
    LinkList.append(a['href'])

r = re.compile("^/wiki")
barris = list(filter(r.match, LinkList))

LinkTotal = list()
for val in enumerate(barris):
    LinkTotal.append("https://es.wikipedia.org" + val[1])

# %% [markdown]
# Links of the website referring to Wikipedia pages are stored in the **val** tuple. Here is the first value:

# %%
LinkTotal[0]
# Out:
# 'https://es.wikipedia.org/wiki/Distritos_de_Barcelona'

# %% [markdown]
# Now let's separate links of Wikipedia pages of districts and neighbourhoods:

# %%
posDistrictes = [1, 6, 13, 24, 28, 35, 41, 53, 67, 75]
LinkDistrictes = list()
for i in posDistrictes:
    LinkDistrictes.append(LinkTotal[i])

posBarris = list(range(2,6)) + list(range(7, 13)) + list(range(14, 24)) + list(range(25, 28)) + \
list(range(29, 35)) + list(range(36,41)) + list(range(42,53)) + list(range(54,67)) + list(range(68,75)) + \
list(range(76,86))
LinkBarris = list()
for i in posBarris:
    LinkBarris.append(LinkTotal[i])

print("In Barcelona there are", len(LinkDistrictes), "districts an", len(LinkBarris), "neighbourhoods.")
# Out:
# In Barcelona there are 10 districts an 75 neighbourhoods.

# %% [markdown]
# I will define a function which uses a Wikipedia neighbourhood website url as input, and returns the neighbourhood **name**, **latitude** and **longitude** registered in Wikipedia:

# %%
def NameAndLocation(link):
    barri_url= requests.get(link).text
    soupBarri = BeautifulSoup(barri_url,"lxml")
    name = str(soupBarri.findAll("h1", {"id": "firstHeading"})[0].contents[0])
    
    latlon = soupBarri.findAll("span", {"class": "geo"})
    if len(latlon)==0:
        latitude=np.nan
        longitude=np.nan
    else:
        latlon = latlon[0].contents
        latitude=float(latlon[0].contents[0].replace(", ", ""))
        longitude=float(latlon[1].contents[0])
    
    output = [name, latitude, longitude]
    return(output)

# %% [markdown]
# I will apply that function to all neighbourhood links to obtain the data frame. One of the neighbourhoods has no registered coordinates. It is not properly a neighbourhood, but the city port, so I remove it from the list:

# %%
Locations = pd.DataFrame(columns = ['Neighbourhood', 'latitude', 'longitude'])

for i in range(len(LinkBarris)):
    r = NameAndLocation(LinkBarris[i])
    Locations.loc[i] = r

Locations.dropna(axis=0, inplace=True)
Locations.reset_index(drop=True, inplace=True)

Locations.shape
# Out:
# (74, 3)

# %%
Locations.head()
# Out:
#                            Neighbourhood   latitude  longitude
# 0                         La Barceloneta  41.379440   2.189170
# 1             Barrio Gótico de Barcelona  41.382778   2.176944
# 2                               El Raval  41.380000   2.168610
# 3  Sant Pere, Santa Caterina i la Ribera  41.384700   2.182600
# 4      La Antigua Izquierda del Ensanche  41.390061   2.155061

# %% [markdown]
# I will store the data frame into a csv file for convenience:

# %%
Locations.to_csv("barrisBCN.csv", index=False)

# %% [markdown]
# ## 2. Using Foursquare to obtain Barcelona venues

# %% [markdown]
# Once we have the position of Barcelona neighbourhoods, we need to obtain Barcelona restaurants. I will explore all Barcelona neighbourhoods, and then filter the venues that are restaurants.
#
# Let's start defining a function to explore a specific location (I have masked Foursquare credentials for privacy):

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# function that explores a location
def explore_location(LocationName, LocationLatitude, LocationLongitude, radius, limit):
    CLIENT_ID = '---------------------' # your Foursquare ID
    CLIENT_SECRET = '----------------------' # your Foursquare Secret
    VERSION = '20190528'
    LIMIT = limit
    
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, LocationLatitude, LocationLongitude, VERSION, radius, LIMIT)
    results = requests.get(url).json()
    items = results['response']['groups'][0]['items']

    dataframe = json_normalize(items) # flatten JSON

    # filter columns
    filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

    # filter the category for each row
    dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

    # clean columns
    dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
    
    size = dataframe_filtered.shape[0]
    dataframe_filtered["Neighbourhood"] = [LocationName for i in range(dataframe_filtered.shape[0])]
    
    return dataframe_filtered

# %% [markdown]
# Let's test how it works in a location:

# %%
testPlace = Locations.loc[0]
resultTestPlace = explore_location(testPlace[0], testPlace[1], testPlace[2], radius=500, limit=10)
resultTestPlace.head()
# Out:
#                       name                categories                  address  \
# 0      Baluard Barceloneta                    Bakery    C. del Baluard, 38-40
# 1               Rumbanroll  Mediterranean Restaurant   C. de la Maquinista, 6
# 2           La Cova Fumada          Tapas Restaurant              Baluard, 56
# 3  Plaça de la Barceloneta                     Plaza  Plaça de la Barceloneta
# 4                      BRO              Burger Joint        C. de Baluard, 34
#
#    cc       city country                 crossStreet  distance  \
# 0  ES  Barcelona  España                C. d'Escuder        67
# 1  ES  Barcelona  España                         NaN       171
# 2  ES  Barcelona  España                         NaN        21
# 3  ES  Barcelona  España                         NaN        92
# 4  ES  Barcelona  España  entre Maquinista i Escuder        87
#
#                                     formattedAddress  \
# 0  [C. del Baluard, 38-40 (C. d'Escuder), 08003 B...
# 1  [C. de la Maquinista, 6, 08003 Barcelona Catal...
# 2    [Baluard, 56, 08003 Barcelona Cataluña, España]
# 3  [Plaça de la Barceloneta, Barcelona Cataluña, ...
# 4  [C. de Baluard, 34 (entre Maquinista i Escuder...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 41.38004687981699...  41.380047  2.189250
# 1  [{'label': 'display', 'lat': 41.38059695009252...  41.380597  2.187807
# 2  [{'label': 'display', 'lat': 41.37925390526866...  41.379254  2.189254
# 3  [{'label': 'display', 'lat': 41.3797389508097,...  41.379739  2.188135
# 4  [{'label': 'display', 'lat': 41.38021387542235...  41.380214  2.189007
#
#   postalCode     state                        id   Neighbourhood
# 0      08003  Cataluña  4c5144e3375c0f475ed8ae93  La Barceloneta
# 1      08003  Cataluña  53249684498ee054d4599642  La Barceloneta
# 2      08003  Cataluña  4b7a8de2f964a520fa302fe3  La Barceloneta
# 3        NaN  Cataluña  4c7a77822d3ba1432b4b91d0  La Barceloneta
# 4      08003  Cataluña  535ea7db498e522c6b801a4f  La Barceloneta

# %% [markdown]
# With this testing, I have obtained the column names of the returned data frame, so I can explore all neighbourhoods:

# %%
venues = pd.DataFrame(columns=resultTestPlace.columns)

for i in range(len(Locations)):
    barri = Locations.loc[i]
    venuesBarri = explore_location(barri[0],  barri[1], barri[2], radius=1000, limit=400)
    venues = pd.concat([venues, venuesBarri], sort=False)
    print(barri[0])
# Out:
# La Barceloneta
# Barrio Gótico de Barcelona
# El Raval
# Sant Pere, Santa Caterina i la Ribera
# La Antigua Izquierda del Ensanche
# La Nueva Izquierda del Ensanche
# La Dreta de l'Eixample
# El Fort Pienc
# Sagrada Familia (barrio de Barcelona)
# Barrio de Sant Antoni (Barcelona)
# La Bordeta (Barcelona)
# La Font de la Guatlla
# Hostafrancs
# La Marina del Prat Vermell
# La Marina de Port
# Pueblo Seco
# Sants
# Sants-Badal
# Montjuic (Barcelona)
# Barrio de Les Corts
# La Maternidad y San Ramón
# Pedralbes
# Putget i Farró
# Sant Gervasi-La Bonanova
# Sant Gervasi-Galvany
# Sarriá
# Las Tres Torres
# Vallvidrera, el Tibidabo i les Planes
# Camp d'en Grassot i Gràcia Nova
# El Coll
# Villa de Gracia
# La Salud (Barcelona)
# Vallcarca y los Penitentes
# El Baix Guinardó
# Can Baró
# El Carmelo
# La Font d'en Fargues
# El Guinardó
# Horta (Barcelona)
# La Clota
# Montbau
# Sant Genís dels Agudells
# La Teixonera
# El Valle de Hebrón
# Can Peguera
# Canyelles (barrio)
# Ciudad Meridiana
# La Guineueta
# Porta (Barcelona)
# La Prosperitat
# Les Roquetes
# Torre Baró
# La Trinitat Nova
# El Turó de la Peira
# Vallbona (barrio)
# Verdún (Barcelona)
# Vilapicina y La Torre Llobeta
# Barón de Viver
# El Buen Pastor (Barcelona)
# El Congrés i els Indians
# Navas (barrio)
# La Sagrera
# San Andrés de Palomar
# La Trinitat Vella
# El Besós y el Maresme
# El Campo del Arpa del Clot
# El Clot
# Diagonal Mar i el Front Marítim del Poblenou
# El Parc i la Llacuna del Poblenou
# Pueblo Nuevo (Barcelona)
# Provençals del Poblenou
# San Martín de Provensals
# La Verneda y la Paz
# La Villa Olímpica del Poblenou

# %% [markdown]
# Let's look at dimensions of venues and how does it look like:

# %%
venues.shape
# Out:
# (6026, 17)

# %%
venues.head()
# Out:
#                       name                categories                  address  \
# 0      Baluard Barceloneta                    Bakery    C. del Baluard, 38-40
# 1               Rumbanroll  Mediterranean Restaurant   C. de la Maquinista, 6
# 2           La Cova Fumada          Tapas Restaurant              Baluard, 56
# 3  Plaça de la Barceloneta                     Plaza  Plaça de la Barceloneta
# 4                      BRO              Burger Joint        C. de Baluard, 34
#
#    cc       city country                 crossStreet distance  \
# 0  ES  Barcelona  España                C. d'Escuder       67
# 1  ES  Barcelona  España                         NaN      171
# 2  ES  Barcelona  España                         NaN       21
# 3  ES  Barcelona  España                         NaN       92
# 4  ES  Barcelona  España  entre Maquinista i Escuder       87
#
#                                     formattedAddress  \
# 0  [C. del Baluard, 38-40 (C. d'Escuder), 08003 B...
# 1  [C. de la Maquinista, 6, 08003 Barcelona Catal...
# 2    [Baluard, 56, 08003 Barcelona Cataluña, España]
# 3  [Plaça de la Barceloneta, Barcelona Cataluña, ...
# 4  [C. de Baluard, 34 (entre Maquinista i Escuder...
#
#                                       labeledLatLngs        lat       lng  \
# 0  [{'label': 'display', 'lat': 41.38004687981699...  41.380047  2.189250
# 1  [{'label': 'display', 'lat': 41.38059695009252...  41.380597  2.187807
# 2  [{'label': 'display', 'lat': 41.37925390526866...  41.379254  2.189254
# 3  [{'label': 'display', 'lat': 41.3797389508097,...  41.379739  2.188135
# 4  [{'label': 'display', 'lat': 41.38021387542235...  41.380214  2.189007
#
#   postalCode     state                        id   Neighbourhood neighborhood
# 0      08003  Cataluña  4c5144e3375c0f475ed8ae93  La Barceloneta          NaN
# 1      08003  Cataluña  53249684498ee054d4599642  La Barceloneta          NaN
# 2      08003  Cataluña  4b7a8de2f964a520fa302fe3  La Barceloneta          NaN
# 3        NaN  Cataluña  4c7a77822d3ba1432b4b91d0  La Barceloneta          NaN
# 4      08003  Cataluña  535ea7db498e522c6b801a4f  La Barceloneta          NaN

# %% [markdown]
# Let's save the results for convenience:

# %%
venues.to_csv("llocsBCN.csv", index=False)

# %% [markdown]
# ## 3. Obtaining Barcelona restaurants

# %% [markdown]
# I have used Forsquare location data to obtain Barcelona venues, exploring each of its neighbourhoods. Now I need to filter these venues to retain restaurants. Let's look at venues categories:

# %%
categories = venues["categories"].unique()
print("There are", len(categories), "different categories in BCN venues.")
# Out:
# There are 286 different categories in BCN venues.

# %% [markdown]
# Using regular expressions, we retain categories related with restaurants:

# %%
r = re.compile('Restaurant|restaurant')
restaurants = list(filter(r.search, categories))
print("There are", len(restaurants), "different restaurant categories in BCN venues.")
# Out:
# There are 57 different restaurant categories in BCN venues.

# %% [markdown]
# From all obtained venues, we need to retain the restaurants, filtering by the selected categories:

# %%
venuesBCNrestaurants = venues.loc[venues['categories'].isin(restaurants)]
venuesBCNrestaurants.shape
# Out:
# (1908, 17)

# %% [markdown]
# ## 3. Clustering the neighbourhoods of Barcelona

# %% [markdown]
# To cluster the neighbourhoods, we start generating dummy variables for each category and venue:

# %%
BCNrestaurants_onehot = pd.get_dummies(venuesBCNrestaurants[['categories']], prefix="", prefix_sep="")
BCNrestaurants_onehot['Neighbourhood'] = venuesBCNrestaurants['Neighbourhood']

fixed_columns = [BCNrestaurants_onehot.columns[-1]] + list(BCNrestaurants_onehot.columns[:-1])
BCNrestaurants_onehot = BCNrestaurants_onehot[fixed_columns]

BCNrestaurants_onehot.head()
# Out:
#     Neighbourhood  African Restaurant  American Restaurant  Arepa Restaurant  \
# 1  La Barceloneta                   0                    0                 0
# 2  La Barceloneta                   0                    0                 0
# 6  La Barceloneta                   0                    0                 0
# 8  La Barceloneta                   0                    0                 0
# 9  La Barceloneta                   0                    0                 0
#
#    Argentinian Restaurant  Asian Restaurant  Brazilian Restaurant  \
# 1                       0                 0                     0
# 2                       0                 0                     0
# 6                       0                 0                     0
# 8                       0                 0                     0
# 9                       0                 0                     0
#
#    Cambodian Restaurant  Chinese Restaurant  Comfort Food Restaurant  \
#

#
#    Vegetarian / Vegan Restaurant  Venezuelan Restaurant  Vietnamese Restaurant
# 1                              0                      0                      0
# 2                              0                      0                      0
# 6                              0                      0                      0
# 8                              0                      0                      0
# 9                              0                      0                      0

# %% [markdown]
# The size of the resulting data frame:

# %%
BCNrestaurants_onehot.shape
# Out:
# (1908, 58)

# %% [markdown]
# Now we obtain the average value of each category for each neighbourhood. This will be the data I will use for clustering:

# %%
BCNrestaurants_grouped = BCNrestaurants_onehot.groupby('Neighbourhood').mean().reset_index()
BCNrestaurants_grouped.head()
# Out:
#                        Neighbourhood  African Restaurant  American Restaurant  \
# 0         Barrio Gótico de Barcelona                 0.0             0.000000
# 1                Barrio de Les Corts                 0.0             0.000000
# 2  Barrio de Sant Antoni (Barcelona)                 0.0             0.000000
# 3                     Barón de Viver                 0.0             0.064516
# 4    Camp d'en Grassot i Gràcia Nova                 0.0             0.000000
#
#    Arepa Restaurant  Argentinian Restaurant  Asian Restaurant  \
# 0               0.0                    0.00          0.000000
# 1               0.0                    0.00          0.055556
# 2               0.0                    0.05          0.000000
# 3               0.0                    0.00          0.032258
# 4               0.0                    0.00          0.000000
#
#    Brazilian Restaurant  Cambodian Restaurant  Chinese Restaurant  \
# 0                   0.0                   0.0            0.000000
# 1                   0.0                   0.0            0.027778
# 2                   0.0                   0.0            0.000000
# 3                   0.0                   0.0            0.032258
# 4                   0.0                   0.0            0.000000
#
#    Comfort Food Restaurant  Dim Sum Restaurant  Dumpling Restaurant  \
# 0                 0.000000                 0.0                  0.0
# 1                 0.027778                 0.0                  0.0
# 2                 0.000000                 0.0                  0.0
# 3                 0.000000                 0.0                  0.0
# 4                 0.000000                 0.0                  0.0
#
#    Empanada Restaurant  Ethiopian Restaurant  Falafel Restaurant  \
# 0                  0.0              0.000000            0.060606
# 1                  0.0              0.027778            0.000000
# 2                  0.0              0.000000            0.000000
# 3                  0.0              0.000000            0.000000
# 4                  0.0              0.000000            0.000000
#
#    Fast Food Restaurant  Fondue Restaurant  French Restaurant  \
# 0              0.000000                0.0                0.0
# 1              0.000000                0.0                0.0
# 2              0.000000                0.0                0.0
# 3              0.064516                0.0                0.0
# 4              0.000000                0.0                0.0
#
#    German Restaurant  Gluten-free Restaurant  Greek Restaurant  \
# 0                0.0                   0.000          0.030303
# 1                0.0                   0.000          0.000000
# 2                0.0                   0.025          0.000000
# 3                0.0                   0.000          0.000000
# 4                0.0                   0.000          0.000000
#
#    Hawaiian Restaurant  Hungarian Restaurant  Indian Restaurant  \
# 0             0.000000                   0.0              0.000
# 1             0.027778                   0.0              0.000
# 2             0.000000                   0.0              0.025
# 3             0.000000                   0.0              0.000
# 4             0.000000                   0.0              0.000
#
#    Indonesian Restaurant  Italian Restaurant  Japanese Restaurant  \
# 0                    0.0            0.121212             0.090909
# 1                    0.0            0.000000             0.055556
# 2                    0.0            0.075000             0.075000
# 3                    0.0            0.129032             0.064516
# 4                    0.0            0.121951             0.097561
#
#    Kebab Restaurant  Korean Restaurant  Latin American Restaurant  \
# 0               0.0            0.00000                    0.00000
# 1               0.0            0.00000                    0.00000
# 2               0.0            0.00000                    0.00000
# 3               0.0            0.00000                    0.00000
# 4               0.0            0.02439                    0.02439
#
#    Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                  0.060606             0.00000                   0.000000
# 1                  0.055556             0.00000                   0.055556
# 2                  0.125000             0.02500                   0.025000
# 3                  0.096774             0.00000                   0.000000
# 4                  0.073171             0.02439                   0.024390
#
#    Modern European Restaurant  Molecular Gastronomy Restaurant  \
# 0                         0
# 1  Vegetarian / Vegan Restaurant              Hawaiian Restaurant
# 2                Thai Restaurant           Gluten-free Restaurant
# 3               Asian Restaurant  Molecular Gastronomy Restaurant
# 4          Vietnamese Restaurant                Korean Restaurant

# %% [markdown]
# Now that we have the information to do the clustering, I will proceed to cluster the neighbourhoods. Note that the study is exploratory, so I cannot evaluate model accuracy. I have chosen to use five clusters:

# %%
# set number of clusters
kclusters = 3

BCNrestaurants_grouped_clustering = BCNrestaurants_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(BCNrestaurants_grouped_clustering)

# check how many elements fall into each cluster
import collections
collections.Counter(kmeans.labels_)
# Out:
# Counter({0: 23, 2: 46, 1: 5})

# %% [markdown]
# For these data, some elements are isolated if we implement four or more clusters. So I have decided to retain five elements. To map the resulting clusters, we need to add the cluster labels and the coordinates for each neighbourhood.

# %%
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
BCNrestaurants_merged = Locations

BCNrestaurants_merged = BCNrestaurants_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), \
                                                   on='Neighbourhood')

BCNrestaurants_merged.head()
# Out:
#                            Neighbourhood   latitude  longitude  \
# 0                         La Barceloneta  41.379440   2.189170
# 1             Barrio Gótico de Barcelona  41.382778   2.176944
# 2                               El Raval  41.380000   2.168610
# 3  Sant Pere, Santa Caterina i la Ribera  41.384700   2.182600
# 4      La Antigua Izquierda del Ensanche  41.390061   2.155061
#
#    Cluster Labels 1st Most Common Venue     2nd Most Common Venue  \
# 0               0      Tapas Restaurant         Paella Restaurant
# 1               0      Tapas Restaurant        Spanish Restaurant
# 2               2      Tapas Restaurant        Spanish Restaurant
# 3               0      Tapas Restaurant        Spanish Restaurant
# 4               2    Spanish Restaurant  Mediterranean Restaurant
#
#       3rd Most Common Venue          4th Most Common Venue  \
# 0  Mediterranean Restaurant             Spanish Restaurant
# 1        Italian Restaurant            Japanese Restaurant
# 2  Mediterranean Restaurant                     Restaurant
# 3        Mexican Restaurant  Vegetarian / Vegan Restaurant
# 4       Japanese Restaurant               Tapas Restaurant
#
#       5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0                Restaurant      Seafood Restaurant    Mexican Restaurant
# 1  Mediterranean Restaurant      Falafel Restaurant      Greek Restaurant
# 2        Italian Restaurant  Argentinian Restaurant   Empanada Restaurant
# 3        Italian Restaurant      Seafood Restaurant      Asian Restaurant
# 4                Restaurant     Peruvian Restaurant    Mexican Restaurant
#
#              8th Most Common Venue     9th Most Common Venue  \
# 0                Indian Restaurant       Hawaiian Restaurant
# 1                 Ramen Restaurant        Seafood Restaurant
# 2              Japanese Restaurant         Indian Restaurant
# 3                       Restaurant  Mediterranean Restaurant
# 4  Molecular Gastronomy Restaurant        Russian Restaurant
#
#           10th Most Common Venue
# 0        Comfort Food Restaurant
# 1                     Restaurant
# 2  Vegetarian / Vegan Restaurant
# 3               Arepa Restaurant
# 4             Seafood Restaurant

# %% [markdown]
# The most visual way to show the results is mapping them using Folium. Here is the result:

# %%
# create map
BCNlatitude = 41.3887901
BCNlongitude = 2.1589899
map_clusters = folium.Map(location=[BCNlatitude, BCNlongitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(BCNrestaurants_merged['latitude'], BCNrestaurants_merged['longitude'], BCNrestaurants_merged['Neighbourhood'], BCNrestaurants_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's review each of the resulting categories:

# %%
BCNrestaurants_merged.loc[BCNrestaurants_merged['Cluster Labels'] == 0, \
                          BCNrestaurants_merged.columns[[0] + list(range(4,14))]]
# Out:
#                             Neighbourhood     1st Most Common Venue  \
# 0                          La Barceloneta          Tapas Restaurant
# 1              Barrio Gótico de Barcelona          Tapas Restaurant
# 3   Sant Pere, Santa Caterina i la Ribera          Tapas Restaurant
# 6                  La Dreta de l'Eixample          Tapas Restaurant
# 10                 La Bordeta (Barcelona)          Tapas Restaurant
# 15                            Pueblo Seco          Tapas Restaurant
# 30                        Villa de Gracia          Tapas Restaurant
# 36                   La Font d'en Fargues          Tapas Restaurant
# 38                      Horta (Barcelona)          Tapas Restaurant
# 41               Sant Genís dels Agudells  Mediterranean Restaurant
# 42                           La Teixonera        Spanish Restaurant
# 44                            Can Peguera          Tapas Restaurant
# 47                           La Guineueta        Spanish Restaurant
# 48                      Porta (Barcelona)          Tapas Restaurant
# 49                         La Prosperitat          Tapas Restaurant
# 52                       La Trinitat Nova        Spanish Restaurant
# 53                    El Turó de la Peira          Tapas Restaurant
# 54                      Vallbona (barrio)          Tapas Restaurant
# 55                     Verdún (Barcelona)        Spanish Restaurant
# 56          Vilapicina y La Torre Llobeta          Tapas Restaurant
# 64                  El Besós y el Maresme          Tapas Restaurant
# 71               San Martín de Provensals          Tapas Restaurant
# 72                    La Verneda y la Paz          Tapas Restaurant
#
#        2nd Most Common Venue      3rd Most Common Venue  \
# 0          Paella Restaurant   Mediterranean Restaurant
# 1         Spanish Restaurant         Italian Restaurant
# 3         Spanish Restaurant         Mexican Restaurant
# 6         Spanish Restaurant                 Restaurant
# 10        Spanish Restaurant                 Restaurant
# 15  Mediterranean Restaurant         Italian Restaurant
# 30  Mediterranean Restaurant  Middle Eastern Restaurant
# 36                Restaurant         Spanish Restaurant
# 38        Spanish Restaurant                 Restaurant
# 41    Argentinian Restaurant           Tapas Restaurant
# 42  Mediterranean Restaurant           Tapas Restaurant
# 44        Spanish Restaurant                 Restaurant
# 47          Tapas Restaurant                 Restaurant
# 48        Spanish Restaurant         Italian Restaurant
# 49        Spanish Restaurant                 Restaurant
# 52          Tapas Restaurant                 Restaurant
# 53        Spanish Restaurant                 Restaurant
# 54     Vietnamese Restaurant         Falafel Restaurant
# 55          Tapas Restaurant                 Restaurant
# 56                Restaurant         Spanish Restaurant
# 64        Spanish Restaurant                 Restaurant
# 71        Spanish Restaurant   Mediterranean Restaurant
# 72      Fast Food Restaurant   Mediterranean Restaurant
#
#             4th Most Common Venue     5th Most Common Venue  \
# 0              Spanish Restaurant                Restaurant
# 1             Japanese Restaurant  Mediterranean Restaurant
# 3   Vegetarian / Vegan Restaurant        Italian Restaurant
# 6        Mediterranean Restaurant        Seafood Restaurant
# 10       Mediterranean Restaurant       Japanese Restaurant
# 15             Spanish Restaurant       Peruvian Restaurant
# 30                     Restaurant        Italian Restaurant
# 36             Italian Restaurant  Mediterranean Restaurant
# 38             Italian Restaurant  Mediterranean Restaurant
# 41          Vietnamese Restaurant      Fast Food Restaurant
# 42         Argentinian Restaurant        Chinese Restaurant
# 44             Seafood Restaurant  Mediterranean Restaurant
# 47             Seafood Restaurant      Fast Food Restaurant
# 48                     Restaurant          Asian Restaurant
# 49             Falafel Restaurant       Japanese Restaurant
# 52          Vietnamese Restaurant        Italian Restaurant
# 53             Seafood Restaurant  Mediterranean Restaurant
# 54            Japanese Restaurant        Italian Restaurant
# 55             Seafood Restaurant      Fast Food Restaurant
# 56               Asian Restaurant        Falafel Restaurant
# 64             Italian Restaurant  Mediterranean Restaurant
# 71               Asian Restaurant        Italian Restaurant
# 72             Spanish Restaurant          Asian Restaurant
#
#             6th Most Common Venue     7th Most Common Venue  \
# 0              Seafood Restaurant        Mexican Restaurant
# 1              Falafel Restaurant          Greek Restaurant
# 3              Seafood Restaurant          Asian Restaurant
# 6             Japanese Restaurant      Hungarian Restaurant
# 10      Middle Eastern Restaurant        Italian Restaurant
# 15                     Restaurant       Japanese Restaurant
# 30               Asian Restaurant          Sushi Restaurant
# 36  Vegetarian / Vegan Restaurant          Asian Restaurant
# 38  Vegetarian / Vegan Restaurant          Asian Restaurant
# 41             Italian Restaurant     Indonesian Restaurant
# 42          Vietnamese Restaurant         French Restaurant
# 44             Italian Restaurant        Chinese Restaurant
# 47            Japanese Restaurant  Mediterranean Restaurant
# 48      South American Restaurant        Falafel Restaurant
# 49           Fast Food Restaurant    Argentinian Restaurant
# 52          Indonesian Restaurant         Indian Restaurant
# 53             Italian Restaurant        Chinese Restaurant
# 54          Indonesian Restaurant         Indian Restaurant
# 55            Japanese Restaurant  Mediterranean Restaurant
# 56             Italian Restaurant       Japanese Restaurant
# 64                Udon Restaurant         Indian Restaurant
# 71           Fast Food Restaurant        Falafel Restaurant
# 72          Vietnamese Restaurant        Italian Restaurant
#
#         8th Most Common Venue     9th Most Common Venue  \
# 0           Indian Restaurant       Hawaiian Restaurant
# 1            Ramen Restaurant        Seafood Restaurant
# 3                  Restaurant  Mediterranean Restaurant
# 6      Argentinian Restaurant        Italian Restaurant
# 10        Peruvian Restaurant      Ethiopian Restaurant
# 15         Seafood Restaurant        Mexican Restaurant
# 30         Spanish Restaurant        Mexican Restaurant
# 36          German Restaurant        Chinese Restaurant
# 38          German Restaurant        Chinese Restaurant
# 41          Indian Restaurant      Hungarian Restaurant
# 42          German Restaurant    Gluten-free Restaurant
# 44          German Restaurant      Fast Food Restaurant
# 47         Falafel Restaurant         Fondue Restaurant
# 48           Sushi Restaurant         Fondue Restaurant
# 49  South American Restaurant        Seafood Restaurant
# 52       Hungarian Restaurant       Hawaiian Restaurant
# 53          German Restaurant       Japanese Restaurant
# 54       Hungarian Restaurant       Hawaiian Restaurant
# 55         Falafel Restaurant         Fondue Restaurant
# 56           Sushi Restaurant        Seafood Restaurant
# 64       Hungarian Restaurant        Falafel Restaurant
# 71                 Restaurant       Japanese Restaurant
# 72      Indonesian Restaurant         Indian Restaurant
#
#       10th Most Common Venue
# 0    Comfort Food Restaurant
# 1                 Restaurant
# 3           Arepa Restaurant
# 6           Ramen Restaurant
# 10        Mexican Restaurant
# 15          Asian Restaurant
# 30        Seafood Restaurant
# 36          Greek Restaurant
# 38          Greek Restaurant
# 41       Hawaiian Restaurant
# 42          Greek Restaurant
# 44       Japanese Restaurant
# 47         French Restaurant
# 48         French Restaurant
# 49        Mexican Restaurant
# 52          Greek Restaurant
# 53          Asian Restaurant
# 54          Greek Restaurant
# 55         French Restaurant
# 56  Mediterranean Restaurant
# 64          Greek Restaurant
# 71       Empanada Restaurant
# 72      Hungarian Restaurant

# %% [markdown]
# This category includes 23 neighbourhoods (in red in the map). In these neighbourhoods, tapas restaurant is among the most common venues. Tapas restaurants offer small plates (tapas, in Spanish) of Spanish food (e.g., patatas bravas). Tapas are eaten usually in a context of leisure, either by tourist (in the city centre) or by locals (in the north neighbourhoods). Tourist can visit these neighbourhoods (e.g. Horta or Turo de la Peira) for a more authentic tapas experience.

# %%
BCNrestaurants_merged.loc[BCNrestaurants_merged['Cluster Labels'] == 1, \
                          BCNrestaurants_merged.columns[[0] + list(range(4,14))]]
# Out:
#                                    Neighbourhood     1st Most Common Venue  \
# 13                    La Marina del Prat Vermell        Spanish Restaurant
# 18                          Montjuic (Barcelona)  Mediterranean Restaurant
# 46                              Ciudad Meridiana  Mediterranean Restaurant
# 51                                    Torre Baró  Mediterranean Restaurant
# 67  Diagonal Mar i el Front Marítim del Poblenou  Mediterranean Restaurant
#
#        2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 13  Mediterranean Restaurant  Vietnamese Restaurant    Falafel Restaurant
# 18        Spanish Restaurant             Restaurant    Italian Restaurant
# 46     Vietnamese Restaurant   Fast Food Restaurant   Japanese Restaurant
# 51        Spanish Restaurant  Vietnamese Restaurant    Falafel Restaurant
# 67                Restaurant     Spanish Restaurant    Italian Restaurant
#
#     5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 13     Italian Restaurant  Indonesian Restaurant      Indian Restaurant
# 18       Asian Restaurant  Vietnamese Restaurant  Indonesian Restaurant
# 46     Italian Restaurant  Indonesian Restaurant      Indian Restaurant
# 51     Italian Restaurant  Indonesian Restaurant      Indian Restaurant
# 67  Vietnamese Restaurant  Indonesian Restaurant      Indian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 13  Hungarian Restaurant   Hawaiian Restaurant       Greek Restaurant
# 18     Indian Restaurant  Hungarian Restaurant    Hawaiian Restaurant
# 46  Hungarian Restaurant   Hawaiian Restaurant       Greek Restaurant
# 51  Hungarian Restaurant   Hawaiian Restaurant       Greek Restaurant
# 67  Hungarian Restaurant   Hawaiian Restaurant       Greek Restaurant

# %% [markdown]
# The second cluster is the smallest, including only five neighbourhoods, painted in purple in the map. Here the predominant restaurant venue is the Mediterranean restaurant. These restaurants offer pizza and pasta, together with some Spanish specialities. These restaurants can be visited either by leisure or at a working pause at noon. These neighbourhoods have also a varied offer of international cuisine.

# %%
BCNrestaurants_merged.loc[BCNrestaurants_merged['Cluster Labels'] == 2, \
                          BCNrestaurants_merged.columns[[0] + list(range(4,14))]]
# Out:
#                             Neighbourhood     1st Most Common Venue  \
# 2                                El Raval          Tapas Restaurant
# 4       La Antigua Izquierda del Ensanche        Spanish Restaurant
# 5         La Nueva Izquierda del Ensanche  Mediterranean Restaurant
# 7                           El Fort Pienc        Spanish Restaurant
# 8   Sagrada Familia (barrio de Barcelona)                Restaurant
# 9       Barrio de Sant Antoni (Barcelona)          Tapas Restaurant
# 11                  La Font de la Guatlla          Tapas Restaurant
# 12                            Hostafrancs                Restaurant
# 14                      La Marina de Port        Spanish Restaurant
# 16                                  Sants       Japanese Restaurant
# 28                 Sushi Restaurant            Vietnamese Restaurant
# 29             Fast Food Restaurant                Fondue Restaurant
# 31               Chinese Restaurant                 Asian Restaurant
# 32                       Restaurant                  Thai Restaurant
# 33         Mediterranean Restaurant        Middle Eastern Restaurant
# 34               Mexican Restaurant                Paella Restaurant
# 35         Mediterranean Restaurant              Hawaiian Restaurant
# 37                 Asian Restaurant               Turkish Restaurant
# 39                German Restaurant               Chinese Restaurant
# 40                French Restaurant                German Restaurant
# 43                French Restaurant                German Restaurant
# 45               Falafel Restaurant              Japanese Restaurant
# 50                Indian Restaurant             Hungarian Restaurant
# 57              American Restaurant                 Asian Restaurant
# 58                 Asian Restaurant              American Restaurant
# 59              Japanese Restaurant               Mexican Restaurant
# 60               Mexican Restaurant          Comfort Food Restaurant
# 61                 Asian Restaurant                 Swiss Restaurant
# 62             Fast Food Restaurant           Argentinian Restaurant
# 63                German Restaurant           Gluten-free Restaurant
# 65                 Asian Restaurant               Chinese Restaurant
# 66            Vietnamese Restaurant               Chinese Restaurant
# 68          Comfort Food Restaurant               Mexican Restaurant
# 69           Argentinian Restaurant                Paella Restaurant
# 70    Vegetarian / Vegan Restaurant                 Ramen Restaurant
# 73              Moroccan Restaurant        Middle Eastern Restaurant
#
#              10th Most Common Venue
# 2     Vegetarian / Vegan Restaurant
# 4                Seafood Restaurant
# 5            Gluten-free Restaurant
# 7                  Tapas Restaurant
# 8                  Asian Restaurant
# 9            Gluten-free Restaurant
# 11                Paella Restaurant
# 12                 Asian Restaurant
# 14              Hawaiian Restaurant
# 16            Venezuelan Restaurant
# 17          Comfort Food Restaurant
# 19              Hawaiian Restaurant
# 20        Latin American Restaurant
# 21             Fast Food Restaurant
# 22                 Sushi Restaurant
# 23  Molecular Gastronomy Restaurant
# 24       Modern European Restaurant
# 25               Seafood Restaurant
# 26                 Sushi Restaurant
# 27                 Greek Restaurant
# 28                Korean Restaurant
# 29                French Restaurant
# 31                Korean Restaurant
# 32             Brazilian Restaurant
# 33            Vietnamese Restaurant
# 34               Seafood Restaurant
# 35             Hungarian Restaurant
# 37                 Swiss Restaurant
# 39                 Greek Restaurant
# 40           Gluten-free Restaurant
# 43           Gluten-free Restaurant
# 45               Chinese Restaurant
# 50              Hawaiian Restaurant
# 57  Molecular Gastronomy Restaurant
# 58               Chinese Restaurant
# 59               Seafood Restaurant
# 60        South American Restaurant
# 61           Argentinian Restaurant
# 62               Mexican Restaurant
# 63                 Greek Restaurant
# 65          Comfort Food Restaurant
# 66          Comfort Food Restaurant
# 68              Empanada Restaurant
# 69                 Asian Restaurant
# 70              Empanada Restaurant
# 73    Vegetarian / Vegan Restaurant

# %% [markdown]
# The last group covers 46 neighbourhoods, so more than one half of Barcelona. They are painted in light blue in the map. In those neighbourhoods the predominant venues are the Restaurant or Spanish Restaurant, followed by Mediterranean restaurant. We can say that people is going to these restaurants in the working pause. In Spain there is a tradition of making a long work stop (sometimes from 14 to 16) to have a strong lunch, with two plates and dessert. This is offered in Spanish Restaurants and Restaurants, and sometimes in Mediterranean Restaurants as "Menu del dia". So we can expect that most of the revenue of these restaurants will be obtained in midday in working days.
